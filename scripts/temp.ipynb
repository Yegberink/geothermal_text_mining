# %%
import pandas as pd
import os

os.chdir("/Users/Yannick/dev/geothermal_text_mining")
paragraphs =pd.read_csv("output/dutch/text/paragraph_locations_ollama.csv")
sentences =pd.read_csv("output/dutch/text/sentences_with_categories_admin.csv")

# %%
print(paragraphs["newspaper"].value_counts())
# Out:
# newspaper
# Noordhollands Dagblad                     72
# AD/Haagsche Courant                       70
# Nieuwe Oogst                              54
# De Gelderlander                           52
# De Limburger                              41
#                                           ..
# Alphens Nieuwsblad                         1
# Gouwe Koerier                              1
# Zenderstreeknieuws Montfoort-Oudewater     1
# Het Kompas woensdag                        1
# Content Type|Narrowed by|                  1
# Name: count, Length: 73, dtype: int64
